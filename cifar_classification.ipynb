# %% [markdown]
# # CIFAR10 Classification Problem

# %% [markdown]
# 🎯 **Exercise objectives**
#
# 1. Implement a CNN to solve a **`10-class classification problem`**
# 2. Enhance the CNN's performance with **`Data Augmentation Techniques`**
# 3. Experiment the **`Acceleration of GPU for Image Processing with Google Colab`**
#
# <hr>
#
#
# 👏 You should now have a better feeling of:
# * how CNNs works,
# * and especially how the convolutions are affecting images to detect specific features.
#
# 🚀 It's time to play with images that are a bit more complex than the handwritten digits or the triangles/circles.
#
# 🎨 From [Wikipedia](https://en.wikipedia.org/wiki/CIFAR-10) (*click on the link for further information*):
#
# > The **`CIFAR-10`** dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.
#
# <img src="https://people.minesparis.psl.eu/fabien.moutarde/ES_MachineLearning/mini-projets/cifar10_notebook_fichiers/cifar_10.png">
#
# ⭐️ This dataset is emblematic in the research community as many enhancements for image recognition have been achieved on this dataset. Once researchers achieved great performances on this dataset, they moved to a more advanced one, the CIFAR-100.
#
# From the [University of Toronto](https://www.cs.toronto.edu/~kriz/cifar.html):
#
# > This dataset is just like the CIFAR-10, except it has 100 classes containing 600 images each. There are 500 training images and 100 testing images per class. The 100 classes in the CIFAR-100 are grouped into 20 superclasses. Each image comes with a "fine" label (the class to which it belongs) and a "coarse" label (the superclass to which it belongs).
# Here is the list of classes in the CIFAR-100:
#
#
# 🔥 In this notebook, let's implement a CNN to distinguish the 10 categories from the CIFAR-10 dataset.
#
# ❗️ Again, remember that until 10 years ago, this problem was very challenging for the entire research community. As you have been sharpening your CNN skills, it's time to shine !

# %% [markdown]
# ## (0) Colab

# %% [markdown]
# You are strongly advised to use **`Google Colab`** for this challenge and the rest of this Deep Learning Module.
#
# * Read this <a href="https://kitt.lewagon.com/knowledge/tutorials/data_google_colab">tutorial on Kitt</a>
#
# *  **If you follow our advice to use Colab, make sure to use the GPU acceleration** by clicking on:
#     * `Runtime` $\rightarrow$ `Change runtime` $\rightarrow$ `GPU`

# %% [markdown]
# ## (1) Loading the CIFAR10 Dataset

# %% [markdown]
# ❓ **Question: Loading the CIFAR10 Dataset** ❓
#
#
# * 🎁 We took care of the  `data loading and preprocessing` for you.
# * ▶️ Just run the following cell and make sure you understand the code.

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np

(images_train, labels_train), (images_test, labels_test) = cifar10.load_data()
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %% [markdown]
# ### (1.1) Working on a smaller dataset  ?

# %% [markdown]
# ❓ **Question about the training size**❓
#
# * $50 000$ images may take a long time to train...
# * 👨🏻‍🏫 **Always start with a subsample to iterate quickly** before scaling up 🏫
# * Run the next cell where we are dividind the dataset size by `reduction_factor = 10`. Don't try to increase it unless we ask you to do so...

# %%
# Considering only 1/10th of the 50_000 images
reduction_factor = 10

# Choosing the random indices of small train set and small test set
idx_train =  np.random.choice(len(images_train), round(len(images_train)/reduction_factor))
idx_test =  np.random.choice(len(images_test), round(len(images_test)/reduction_factor))

# Collecting the two subsamples images_train_small and images_test_small from images_train and images_test
images_train_small = images_train[idx_train]
images_test_small = images_test[idx_test]
# and their corresponding labels
labels_train_small = labels_train[idx_train]
labels_test_small = labels_test[idx_test]

print("------------------ Before -----------------")
print(images_train.shape, images_test.shape)

print("")

print("--- After applying the reduction factor ---")
print(images_train_small.shape, images_test_small.shape)

print("")
print("-"*43)

unique, counts = np.unique(labels_train_small, return_counts=True)
dict(zip(unique, counts))
# Out:
# ------------------ Before -----------------
# (50000, 32, 32, 3) (10000, 32, 32, 3)
#
# --- After applying the reduction factor ---
# (5000, 32, 32, 3) (1000, 32, 32, 3)
#
# -------------------------------------------
# {0: 503,
#  1: 507,
#  2: 505,
#  3: 529,
#  4: 502,
#  5: 473,
#  6: 491,
#  7: 508,
#  8: 514,
#  9: 468}

# %% [markdown]
# 👇 You are working with images.. so it would be a good idea to show some of them :)

# %%
# Let's plot few images to see what they look like
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(6):
    plt.subplot(1,6, i+1)
    img = images_train[i]
    label = labels_train[i][0]
    plt.imshow(img)
    plt.title(labels[label])

# %% [markdown]
# ### (1.2) Image preprocesing

# %% [markdown]
# 👉 As usual, let's:
# - normalize the pixels' intensities between 0 and 1
# - turn the `labels_train` and `labels_test` into "one-hot-encoded" targets that we will call respectively `y_train` and `y_cat`

# %%
### Normalizing pixels' intensities

X_train = images_train / 255.
X_train_small = images_train_small / 255.
X_test = images_test / 255.
X_test_small = images_test_small / 255.

### Encoding the labels

from tensorflow.keras.utils import to_categorical
y_train = to_categorical(labels_train, 10)
y_train_small = to_categorical(labels_train_small, 10)
y_test = to_categorical(labels_test, 10)
y_test_small = to_categorical(labels_test_small, 10)

# %% [markdown]
# ## (2) Iterate on your CNN architecture using your small training set

# %% [markdown]
# ❓ **Question** ❓ Time to shine ⭐️⭐️⭐️ !
#
# 1. Define the CNN architecture of your choice in an `initialize_model()` function:
# 2. Compile your model in a `compile_model()` method:
# 3. Fit your CNN only on the `small training set` and save the training information in an `history` variable
# ---
# * Feeling lost ?
# * Do you want to improve your performance ?
#
# <details>
#     <summary>🆘 PRO TIPS 🆘  </summary>
#
#
# - Do not forget to add the **`input shape`** of your images to the first layer: it has 3 colors
# - **`Start simple, complexify later `** after several attempts to get better results
# - The task is complex: **`Try at least 3 or 4 convolutions`**, you want your **images to go through different magnifying glasses / kernels from different convolutional layers !**
# - The Kernel Size do not need to be large for such a small picture resolution!
# - Add some **`MaxPooling2D`** (but not too much, otherwise the activation "image" will become too small)
# - Keep `padding = "same"` and `stride = (1,1)` to start with.
# - Once your model overfits, try to add some **`Dropout Layers` to regularize the network**. A good tip is to **increase the Dropout Rate/Strength as you move closer to the prediction layer** to prevent your CNN from overfitting
# - Images are so small on the CIFAR10, you can afford to use a larger batch size (32 or 64) to benefit from even **more GPU parallelization** !
# </details>
#
# ---

# %%
from tensorflow.keras import layers, models

def initialize_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    # YOUR CODE HERE
    model = models.Sequential()

    ### First Convolution & MaxPooling
    model.add(layers.Conv2D(32,(4,4), activation='ReLU', input_shape=(X_train_small[0].shape)))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    
    ### Second Convolution & MaxPooling
    model.add(layers.Conv2D(32,(3,3), activation='ReLU'))
    
    model.add(layers.Conv2D(32,(3,3), activation='ReLU'))
    
    model.add(layers.Conv2D(32,(2,2), activation='ReLU'))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(10, activation='ReLU'))
    
    ### Last layer - Classification Layer with 10 outputs corresponding to 10 digits
    model.add(layers.Dense(10, activation='softmax'))

    return model

# %%
def compile_model(model):
    '''return a compiled model suited for the CIFAR-10 task'''
    # YOUR CODE HERE
    model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])    
    
    return model

# %%
X_train_small.shape
# Out:
# (5000, 32, 32, 3)

# %%
model = initialize_model()
model = compile_model(model)
history = model.fit(X_train_small, y_train_small, validation_split=0.3, epochs = 50)
# Out:
# Epoch 1/50
# 110/110 [==============================] - 2s 10ms/step - loss: 2.2407 - accuracy: 0.1489 - val_loss: 2.1625 - val_accuracy: 0.1927
# Epoch 2/50
# 110/110 [==============================] - 1s 5ms/step - loss: 2.1070 - accuracy: 0.2169 - val_loss: 2.0605 - val_accuracy: 0.2213
# Epoch 3/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.9739 - accuracy: 0.2680 - val_loss: 1.8915 - val_accuracy: 0.3107
# Epoch 4/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.8550 - accuracy: 0.3120 - val_loss: 1.8320 - val_accuracy: 0.3047
# Epoch 5/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.7362 - accuracy: 0.3506 - val_loss: 1.8060 - val_accuracy: 0.3607
# Epoch 6/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.6292 - accuracy: 0.4051 - val_loss: 1.6377 - val_accuracy: 0.4073
# Epoch 7/50
# 110/110 [==============================] - 1s 6ms/step - loss: 1.5574 - accuracy: 0.4231 - val_loss: 1.5663 - val_accuracy: 0.4253
# Epoch 8/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4639 - accuracy: 0.4657 - val_loss: 1.6227 - val_accuracy: 0.4273
# Epoch 9/50
# 110/110 [==============================] - 1s 6ms/step - loss: 1.4017 - accuracy: 0.4783 - val_loss: 1.5076 - val_accuracy: 0.4547
# Epoch 10/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3305 - accuracy: 0.5003 - val_loss: 1.5567 - val_accuracy: 0.4553
# Epoch 11/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2665 - accuracy: 0.5360 - val_loss: 1.5106 - val_accuracy: 0.4587
# Epoch 12/50
# 110/110 [==============================] - 1s 6ms/step - loss: 1.2010 - accuracy: 0.5583 - val_loss: 1.6052 - val_accuracy: 0.4613
# Epoch 13/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1302 - accuracy: 0.5877 - val_loss: 1.6391 - val_accuracy: 0.4427
# Epoch 14/50
# 110/110 [==============================] - 1s 6ms/step - loss: 1.0591 - accuracy: 0.6100 - val_loss: 1.5717 - val_accuracy: 0.4773
# Epoch 15/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.0114 - accuracy: 0.6323 - val_loss: 1.6202 - val_accuracy: 0.4660
# Epoch 16/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.9344 - accuracy: 0.6626 - val_loss: 1.6241 - val_accuracy: 0.4787
# Epoch 17/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.8979 - accuracy: 0.6626 - val_loss: 1.6623 - val_accuracy: 0.4500
# Epoch 18/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.8256 - accuracy: 0.6914 - val_loss: 1.8052 - val_accuracy: 0.4427
# Epoch 19/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.7853 - accuracy: 0.7063 - val_loss: 1.7316 - val_accuracy: 0.4640
# Epoch 20/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.7243 - accuracy: 0.7394 - val_loss: 1.8329 - val_accuracy: 0.4747
# Epoch 21/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6800 - accuracy: 0.7569 - val_loss: 1.9975 - val_accuracy: 0.4707
# Epoch 22/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6163 - accuracy: 0.7740 - val_loss: 1.9979 - val_accuracy: 0.4780
# Epoch 23/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.5636 - accuracy: 0.7926 - val_loss: 2.0005 - val_accuracy: 0.4773
# Epoch 24/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.5677 - accuracy: 0.7960 - val_loss: 2.2538 - val_accuracy: 0.4687
# Epoch 25/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.4737 - accuracy: 0.8203 - val_loss: 2.2515 - val_accuracy: 0.4813
# Epoch 26/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.4209 - accuracy: 0.8483 - val_loss: 2.4408 - val_accuracy: 0.4680
# Epoch 27/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.3949 - accuracy: 0.8614 - val_loss: 2.7043 - val_accuracy: 0.4587
# Epoch 28/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3867 - accuracy: 0.8540 - val_loss: 2.6713 - val_accuracy: 0.4853
# Epoch 29/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3255 - accuracy: 0.8831 - val_loss: 2.8059 - val_accuracy: 0.4773
# Epoch 30/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2810 - accuracy: 0.9054 - val_loss: 2.7782 - val_accuracy: 0.4753
# Epoch 31/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2920 - accuracy: 0.8920 - val_loss: 2.8792 - val_accuracy: 0.4613
# Epoch 32/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2816 - accuracy: 0.9011 - val_loss: 3.1382 - val_accuracy: 0.4633
# Epoch 33/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2188 - accuracy: 0.9263 - val_loss: 3.1926 - val_accuracy: 0.4680
# Epoch 34/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2053 - accuracy: 0.9303 - val_loss: 3.6465 - val_accuracy: 0.4727
# Epoch 35/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2248 - accuracy: 0.9197 - val_loss: 3.7699 - val_accuracy: 0.4600
# Epoch 36/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.1670 - accuracy: 0.9463 - val_loss: 4.0310 - val_accuracy: 0.4533
# Epoch 37/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.1912 - accuracy: 0.9317 - val_loss: 3.8117 - val_accuracy: 0.4727
# Epoch 38/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.1500 - accuracy: 0.9509 - val_loss: 4.3285 - val_accuracy: 0.4347
# Epoch 39/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2671 - accuracy: 0.9057 - val_loss: 3.9989 - val_accuracy: 0.4553
# Epoch 40/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2131 - accuracy: 0.9297 - val_loss: 3.9866 - val_accuracy: 0.4547
# Epoch 41/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.1190 - accuracy: 0.9623 - val_loss: 4.2874 - val_accuracy: 0.4593
# Epoch 42/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0848 - accuracy: 0.9746 - val_loss: 4.6887 - val_accuracy: 0.4600
# Epoch 43/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0756 - accuracy: 0.9760 - val_loss: 4.8800 - val_accuracy: 0.4607
# Epoch 44/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0673 - accuracy: 0.9794 - val_loss: 4.8549 - val_accuracy: 0.4627
# Epoch 45/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2237 - accuracy: 0.9251 - val_loss: 4.4237 - val_accuracy: 0.4533
# Epoch 46/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2420 - accuracy: 0.9206 - val_loss: 4.3864 - val_accuracy: 0.4400
# Epoch 47/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.1743 - accuracy: 0.9449 - val_loss: 4.7303 - val_accuracy: 0.4460
# Epoch 48/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.1144 - accuracy: 0.9671 - val_loss: 4.8506 - val_accuracy: 0.4547
# Epoch 49/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.0792 - accuracy: 0.9729 - val_loss: 4.9858 - val_accuracy: 0.4727
# Epoch 50/50
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0643 - accuracy: 0.9811 - val_loss: 5.2266 - val_accuracy: 0.4627

# %% [markdown]
# ❓ **Question: History of your training** ❓
#
# Run the following function on the previous history
# _(keep the default arguments, these are intended for future plots in the notebook)_

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label='train' + exp_name)
    ax1.plot(history.history['val_loss'], label='val' + exp_name)
    ax1.set_ylim(0., 2.2)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_ylim(0.25, 1.)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

# %%
plot_history(history);

# %% [markdown]
# ❓ **Question: Evaluating your CNN** ❓
#
# * Evaluate your model on the test data and compare it with a baseline accuracy.
# * Are you satisfied with these performances ?
# * Look at the `PRO TIPS` above and iterate a bit if you want to improve your performances!

# %%
# YOUR CODE HERE
model.evaluate(X_test_small, y_test_small)
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 2.3035 - accuracy: 0.0840
# [2.3034918308258057, 0.08399999886751175]

# %% [markdown]
# ## (3) Increase the size of your training data

# %% [markdown]
# ❓ **Question: train your model on the full dataset** ❓
#
# - Switch to **Colab** if you haven't done it before
# - Make sure to use the **GPU acceleration** by clicking on `Runtime` $\rightarrow$ `Change runtime` $\rightarrow$ `GPU`
#
# 💡 Training neural networks on images (in each batch) can be parallelized, and this **`parallelization procedure`** can be done on **`GPU`**.
#
# ---

# %%
# YOUR CODE HERE
model = initialize_model()
model = compile_model(model)
history = model.fit(X_train, y_train, validation_split=0.3, epochs = 50)
# Out:
# Epoch 1/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.9224 - accuracy: 0.2843 - val_loss: 1.5831 - val_accuracy: 0.4183
# Epoch 2/50
# 1094/1094 [==============================] - 5s 5ms/step - loss: 1.4869 - accuracy: 0.4503 - val_loss: 1.4162 - val_accuracy: 0.4727
# Epoch 3/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.3322 - accuracy: 0.5075 - val_loss: 1.3791 - val_accuracy: 0.4991
# Epoch 4/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.2443 - accuracy: 0.5442 - val_loss: 1.2486 - val_accuracy: 0.5495
# Epoch 5/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1682 - accuracy: 0.5722 - val_loss: 1.1984 - val_accuracy: 0.5671
# Epoch 6/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.1173 - accuracy: 0.5906 - val_loss: 1.1967 - val_accuracy: 0.5742
# Epoch 7/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0589 - accuracy: 0.6144 - val_loss: 1.1609 - val_accuracy: 0.5889
# Epoch 8/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 1.0191 - accuracy: 0.6273 - val_loss: 1.1084 - val_accuracy: 0.6029
# Epoch 9/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9821 - accuracy: 0.6411 - val_loss: 1.0928 - val_accuracy: 0.6185
# Epoch 10/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 0.9493 - accuracy: 0.6583 - val_loss: 1.0782 - val_accuracy: 0.6239
# Epoch 11/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.9128 - accuracy: 0.6685 - val_loss: 1.1343 - val_accuracy: 0.6059
# Epoch 12/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.8855 - accuracy: 0.6783 - val_loss: 1.1048 - val_accuracy: 0.6178
# Epoch 13/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.8541 - accuracy: 0.6881 - val_loss: 1.0970 - val_accuracy: 0.6218
# Epoch 14/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.8347 - accuracy: 0.6965 - val_loss: 1.0984 - val_accuracy: 0.6265
# Epoch 15/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.8091 - accuracy: 0.7055 - val_loss: 1.1061 - val_accuracy: 0.6301
# Epoch 16/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.7823 - accuracy: 0.7147 - val_loss: 1.0849 - val_accuracy: 0.6345
# Epoch 17/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.7631 - accuracy: 0.7207 - val_loss: 1.1468 - val_accuracy: 0.6170
# Epoch 18/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.7487 - accuracy: 0.7243 - val_loss: 1.1889 - val_accuracy: 0.6152
# Epoch 19/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.7200 - accuracy: 0.7330 - val_loss: 1.1465 - val_accuracy: 0.6297
# Epoch 20/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.7046 - accuracy: 0.7423 - val_loss: 1.2039 - val_accuracy: 0.6130
# Epoch 21/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.6855 - accuracy: 0.7480 - val_loss: 1.2133 - val_accuracy: 0.6196
# Epoch 22/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.6702 - accuracy: 0.7530 - val_loss: 1.2766 - val_accuracy: 0.6069
# Epoch 23/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.6543 - accuracy: 0.7602 - val_loss: 1.2781 - val_accuracy: 0.6132
# Epoch 24/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.6374 - accuracy: 0.7664 - val_loss: 1.2985 - val_accuracy: 0.6089
# Epoch 25/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.6200 - accuracy: 0.7723 - val_loss: 1.3080 - val_accuracy: 0.6164
# Epoch 26/50
# 1094/1094 [==============================] - 5s 5ms/step - loss: 0.6248 - accuracy: 0.7686 - val_loss: 1.3074 - val_accuracy: 0.6068
# Epoch 27/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.5866 - accuracy: 0.7837 - val_loss: 1.3252 - val_accuracy: 0.6255
# Epoch 28/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.5709 - accuracy: 0.7877 - val_loss: 1.3776 - val_accuracy: 0.6098
# Epoch 29/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.5680 - accuracy: 0.7867 - val_loss: 1.3628 - val_accuracy: 0.6149
# Epoch 30/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.5504 - accuracy: 0.7965 - val_loss: 1.3852 - val_accuracy: 0.6135
# Epoch 31/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.5396 - accuracy: 0.8016 - val_loss: 1.4295 - val_accuracy: 0.6129
# Epoch 32/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.5287 - accuracy: 0.8030 - val_loss: 1.5030 - val_accuracy: 0.5990
# Epoch 33/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.5172 - accuracy: 0.8063 - val_loss: 1.5220 - val_accuracy: 0.6060
# Epoch 34/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4984 - accuracy: 0.8155 - val_loss: 1.5724 - val_accuracy: 0.6064
# Epoch 35/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.5040 - accuracy: 0.8107 - val_loss: 1.5905 - val_accuracy: 0.6040
# Epoch 36/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4903 - accuracy: 0.8162 - val_loss: 1.5895 - val_accuracy: 0.6037
# Epoch 37/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4703 - accuracy: 0.8269 - val_loss: 1.6186 - val_accuracy: 0.5987
# Epoch 38/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4715 - accuracy: 0.8254 - val_loss: 1.6435 - val_accuracy: 0.6056
# Epoch 39/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4533 - accuracy: 0.8325 - val_loss: 1.6695 - val_accuracy: 0.5999
# Epoch 40/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4485 - accuracy: 0.8316 - val_loss: 1.7189 - val_accuracy: 0.6066
# Epoch 41/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4388 - accuracy: 0.8367 - val_loss: 1.7200 - val_accuracy: 0.6004
# Epoch 42/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4316 - accuracy: 0.8378 - val_loss: 1.7715 - val_accuracy: 0.5971
# Epoch 43/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4252 - accuracy: 0.8419 - val_loss: 1.7803 - val_accuracy: 0.5989
# Epoch 44/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4201 - accuracy: 0.8438 - val_loss: 1.8686 - val_accuracy: 0.5957
# Epoch 45/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4135 - accuracy: 0.8457 - val_loss: 1.8375 - val_accuracy: 0.5957
# Epoch 46/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.4010 - accuracy: 0.8500 - val_loss: 1.9175 - val_accuracy: 0.5921
# Epoch 47/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.3925 - accuracy: 0.8547 - val_loss: 1.9030 - val_accuracy: 0.5914
# Epoch 48/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.3791 - accuracy: 0.8584 - val_loss: 2.0163 - val_accuracy: 0.5891
# Epoch 49/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.3761 - accuracy: 0.8610 - val_loss: 1.9796 - val_accuracy: 0.5992
# Epoch 50/50
# 1094/1094 [==============================] - 6s 5ms/step - loss: 0.3903 - accuracy: 0.8549 - val_loss: 1.9522 - val_accuracy: 0.5933

# %% [markdown]
# You should witness significant performance improvement
#
# Welcome to the Deep Learning paradigm, where big data makes a significant difference.
#
# But what happens if I can access only a limited amount of pictures ? Think about biologists studying rare species. What can they do ?
# * To improve the accuracy of a model without much work, we can **generate new data**.
# * The process is called... ⭐️ **`Data Augmentation`** ⭐️ !
# </details>

# %% [markdown]
# ## (4) Data augmentation

# %% [markdown]
# * 👩🏻‍🏫 <b><u>Data Augmentation</u></b>
#     * This technique is widely-used technique consists in applying little transformations to the input images without changing their labels: ***mirroring***, ***cropping***, ***intensity changes***, etc...
#     * The _improved performance_ simply results from the CNN training with more images (the original pictures + the "augmented" ones).
#
#
# * 👉 <b><u>Theoretically:</u></b>
#     * (1) We could generate these new images by applying some transformations on copies of the original picturnes
#     * (2) Train the model on the original images + new images.
#
#
# * 🚨  <b><u>Problem:</u></b>
#     * Such a procedure requires to store all these images in memory...
#     * It can be very intensive, to the point that your computer RAM cannot hold any additional new image
#
#
# * 🦄 <b><u>In Practice:</u></b>
#     * When a Neural Network operates a forward/backward propagation, it requires to see only 16 pictures at a time if you chose $ batch size = 16 $ for example. It doesn't need to store neither all the original images nor the augmented images in the RAM.
#     * For this reason, we will **augment the data on the fly (batch per batch)**. What does it mean ? For every epoch and every batch, during the ***.fit()*** training procedure, we will:
#         1. Generate some `augmented data/images`
#         2. Fit the model on the images and their augmented versions
#         3. Delete the images and their augmented versions from the RAM
#         4. Repeat steps 1-2-3
#
# * 📚 <a href= "https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator"><b><u>tf/keras/preprocessing/image/ImageDataGenerator:</u></b></a>

# %% [markdown]
# ❓ **Question: using an ImageDataGenerator** ❓
#
# Look at the following code down below 👇
# * The general syntax may look strange but don't worry:
#     * First, focus on the arguments of the *ImageDataGenerator* which defines the augmentation techniques that we are using
#     * and then check the <a href="https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator">**`ImageDataGenerator`**</a> documentation later

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=(0.8, 1.2),
    ) 

datagen.fit(X_train)
datagen

# %%
X_augmented_iterator = datagen.flow(X_train, shuffle=False, batch_size=1)
X_augmented_iterator

# %% [markdown]
# ❗️ Always **visualize the augmented images** in order to double-check whether you can still recognize the labels yourself or not ❗️

# %%
import numpy as np

for i, (raw_image, augmented_image) in enumerate(zip(X_train, X_augmented_iterator)):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2))
    ax1.imshow(raw_image)
    ax2.imshow(augmented_image[0])
    plt.show()
    
    if i > 10:
        break

# %% [markdown]
# ❗ **Remarks** ❗
#
# * Each image from **`X_augmented_iterator`** is an ***augmented image*** of one image located in the original `X_train` image dataset
# * This augmentation process is done once per epoch.
# * During one epoch, the model will:
#     1. *create the augmented version* of each picture from `X_train`,
#     2. for each image of `X_train`, *the model will randomly pick either the original version in `X_train` or its augmented version in `X_augmented_iterator`*
#     3. and the model will be *fitted on the combination of some original images + some augmented images*
#
# ---

# %% [markdown]
# ❓ **Question: what is the validation set when we have augmented images** ❓
#
# * Previously, we used the `validation_split` argument to let the model separate the training set into a Train/Validation split when fitting the model for each epoch.
# * It is not possible to use this kind of Train/Val Split here as **using an image in the training set and its transformation in the validation set is considered as a `data leakage`** !.
# * Therefore, we have to define the **`validation_data`** manually with the following commands: take time to understand the cell down below:👇

# %%
from tensorflow.keras.callbacks import EarlyStopping

# The model
model_aug = initialize_model()
model_aug = compile_model(model_aug)

# The data generator
X_tr = X_train[:40000]
y_tr = y_train[:40000]
X_val = X_train[40000:]
y_val = y_train[40000:]
train_flow = datagen.flow(X_tr, y_tr, batch_size=64)

# The early stopping criterion
es = EarlyStopping(patience=3)

# The fit
history_aug = model_aug.fit(train_flow, 
                        epochs=50, 
                        callbacks=[es], 
                        validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.9068 - accuracy: 0.2905 - val_loss: 1.6680 - val_accuracy: 0.3822
# Epoch 2/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.6350 - accuracy: 0.3980 - val_loss: 1.5106 - val_accuracy: 0.4395
# Epoch 3/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.5160 - accuracy: 0.4465 - val_loss: 1.4408 - val_accuracy: 0.4683
# Epoch 4/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.4411 - accuracy: 0.4772 - val_loss: 1.3619 - val_accuracy: 0.5031
# Epoch 5/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.3881 - accuracy: 0.4997 - val_loss: 1.2899 - val_accuracy: 0.5421
# Epoch 6/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.3543 - accuracy: 0.5099 - val_loss: 1.2566 - val_accuracy: 0.5497
# Epoch 7/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.3098 - accuracy: 0.5297 - val_loss: 1.1959 - val_accuracy: 0.5726
# Epoch 8/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.2721 - accuracy: 0.5450 - val_loss: 1.1272 - val_accuracy: 0.5979
# Epoch 9/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.2474 - accuracy: 0.5533 - val_loss: 1.0931 - val_accuracy: 0.6109
# Epoch 10/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.2205 - accuracy: 0.5642 - val_loss: 1.1104 - val_accuracy: 0.6085
# Epoch 11/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.2016 - accuracy: 0.5674 - val_loss: 1.0961 - val_accuracy: 0.6079
# Epoch 12/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.1863 - accuracy: 0.5761 - val_loss: 1.0676 - val_accuracy: 0.6162
# Epoch 13/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.1612 - accuracy: 0.5880 - val_loss: 1.0880 - val_accuracy: 0.6115
# Epoch 14/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.1493 - accuracy: 0.5889 - val_loss: 1.0895 - val_accuracy: 0.6167
# Epoch 15/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.1318 - accuracy: 0.5984 - val_loss: 0.9909 - val_accuracy: 0.6493
# Epoch 16/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.1202 - accuracy: 0.6008 - val_loss: 0.9833 - val_accuracy: 0.6492
# Epoch 17/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.1030 - accuracy: 0.6073 - val_loss: 0.9888 - val_accuracy: 0.6505
# Epoch 18/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.0951 - accuracy: 0.6115 - val_loss: 1.0363 - val_accuracy: 0.6387
# Epoch 19/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.0767 - accuracy: 0.6173 - val_loss: 0.9473 - val_accuracy: 0.6617
# Epoch 20/50
# 625/625 [==============================] - 19s 31ms/step - loss: 1.0640 - accuracy: 0.6220 - val_loss: 1.0401 - val_accuracy: 0.6398
# Epoch 21/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.0531 - accuracy: 0.6277 - val_loss: 0.9845 - val_accuracy: 0.6545
# Epoch 22/50
# 625/625 [==============================] - 19s 30ms/step - loss: 1.0411 - accuracy: 0.6316 - val_loss: 0.9973 - val_accuracy: 0.6538

# %% [markdown]
# 🚨 The training can be quite long here...
#
# 👉 Feel free to move on to the next exer|ise and come back later to this notebook to finish the last questions

# %% [markdown]
# ❓ **Question: How did the model with an augmented dataset perform ?** ❓
#
# Let's plot the previous and current run histories. What do you think of the data augmentation?

# %%
# YOUR CODE HERE
plot_history(history);

# %% [markdown]
# 🥡 <b><u>Some takeaways from Data Augmentation:</u></b>
#
# * Data augmentation may not improve your performance easily...
#
# * Here it even decreased the performance!
#
# * Its impact strongly depends on
#     * the model architecture you used
#     * the learning rate,
#     * the type of augmentation chosen, etc...
#
# * Image classification is an art that requires months and years of practice to master!
#
# 🚨 **Don't spend too much time trying to finetune your model for the moment !  You have 3 other interesting challenges to investigate!**. 🚨
#
# 📚 [Here is a good example of a solution for future reference](https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/).<br>
# They managed to reach an accuracy level of approx. 80%

# %% [markdown]
# ---
#
# 🏁 **Congratulations** 🏁
#
# 1. Download this notebook from your `Google Drive` or directly from `Google Colab`
# 2. Drag-and-drop it from your `Downloads` folder to your local `[GITHUB_USERNAME]/data-challenges/06-Deep-Learning/03-Convolutional-Neural-Networks/03-Cifar-Classification`
#
#
# 💾 Don't forget to push your
#
# 3. Follow the usual procedure on your terminal in the `06-Deep-Learning/03-Convolutional-Neural-Networks/03-Cifar-Classification` folder:
#       * *git add cifar_classification.ipynb*
#       * *git commit -m "I am the god of CNNs"*
#       * *git push origin master*
#
# *Hint*: To find where this Colab notebook has been saved, click on `File` $\rightarrow$ `Locate in Drive`.
#
# 🚀 It is time to move on to the **Transfer Learning** challenge!
